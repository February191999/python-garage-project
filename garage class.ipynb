# %%
class Garage():
    '''
        Has 3 attributes: tickets, parkingSpaces, and currentTicket.
        
        
        tickets is expected to be a list,
        parkingSpaces is expected to be a list,
        and currentTicket is expected to be a dictionary.
        
        Class has 3 methods: takeTicket, payForParking, and leaveGarage.
        
        
        takeTicket decreases the amount of tickets available in the tickets and parkingSpaces list by 1.
        
        payForParking displays an input that waits for an amount from the user and stores it in a variable,
        if the payment variable is not empty (meaning ticket has been paid) then display a message to the user
        that their ticket has been paid and they have 15 mins to leave. This updates the currentTicket dictionary 
        key paid to True.
        
        leaveGarage displays a message of "Thank You, have a nice day!" if ticket has been paid. If ticket has not been paid, 
        display an input prompt for payment. Once paid, display message "Thank You, have a nice day!" After ticket has been paid,
        update parkingSpaces list and tickets list to increase by 1.
    '''
    
    def __init__(self, tickets, parkingSpaces, currentTicket):
        self.tickets = tickets
        self.parkingSpaces = parkingSpaces
        self.currentTicket = currentTicket
        
    def takeTicket(self, tickets, parkingSpaces):
        taken_ticket = tickets.pop(-1)
        taken_spot = parkingSpaces.pop(-1)
        
    def payForParking(self, currentTicket):
        fee = input("Please pay $1.55 for your parking fee: ")
        if fee != ' ':
            print("Your ticket has been paid, you have 15 mins to leave the garage.")
        
        currentTicket['Paid'] = "True"
    
    def leaveGarage(self, parkingSpaces, tickets):
        tickets.append("parking_ticket")
        parkingSpaces.append("parking_space")
            
            
            

boulderGarage = Garage([], [], {})

def go():
    
    for i in list(range(0, 7)):
        ticket = "parking_ticket"
        boulderGarage.tickets.append(ticket)
    
    for i in list(range(0, 7)):
        spot = "parking_space"
        boulderGarage.parkingSpaces.append(spot)
        
    boulderGarage.currentTicket['Paid'] = "True"
    
    
    while True:
        question = input("What would you like to do? PARK/PAY/LEAVE ")
        
        if question.lower() == 'park':
            boulderGarage.takeTicket(boulderGarage.tickets, boulderGarage.parkingSpaces)
            
            boulderGarage.currentTicket["Paid"] = "False"
            ticket_dict = boulderGarage.currentTicket
            print(ticket_dict)
            
        elif question.lower() == 'pay':
            boulderGarage.payForParking(boulderGarage.currentTicket)
            
        elif question.lower() == 'leave':
            if ticket_dict['Paid'] != 'False':
                print("Thank You, have a nice day!")
            
            if ticket_dict['Paid'] == 'False':
                pay_fee = input("Please pay $1.55 for your parking fee: ")
            
                if pay_fee != ' ':
                    print("Your ticket has been paid, you have 15 mins to leave the garage. Thank You, have a nice day!")
                    boulderGarage.leaveGarage(boulderGarage.tickets, boulderGarage.parkingSpaces)
go()
# Out:
# What would you like to do? PARK/PAY/LEAVE park
# {'Paid': 'False'}
# What would you like to do? PARK/PAY/LEAVE pay
# Please pay $1.55 for your parking fee: $1.55
# Your ticket has been paid, you have 15 mins to leave the garage.
# What would you like to do? PARK/PAY/LEAVE leave
# Thank You, have a nice day!
# What would you like to do? PARK/PAY/LEAVE park
# {'Paid': 'False'}
# What would you like to do? PARK/PAY/LEAVE pay
# Please pay $1.55 for your parking fee: $1.55
# Your ticket has been paid, you have 15 mins to leave the garage.
# What would you like to do? PARK/PAY/LEAVE lave
# What would you like to do? PARK/PAY/LEAVE park
# {'Paid': 'False'}
# What would you like to do? PARK/PAY/LEAVE leave
# Please pay $1.55 for your parking fee: $1.55
# Your ticket has been paid, you have 15 mins to leave the garage. Thank You, have a nice day!
